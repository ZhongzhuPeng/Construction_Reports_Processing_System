# %%
FREQUENCY_THRESHOLD = 0.4
HORIZONTAL_DISTANCE = 500
VERTICAL_DISTANCE = 100
BODY_START_POS = 660    # the starting position of the body part

# %% [markdown]
# # Extract text and its position

# %%
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfpage import PDFTextExtractionNotAllowed
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice
from pdfminer.layout import LAParams
from pdfminer.converter import PDFPageAggregator
import pdfminer


class pdfPositionHandling:

    def parse_obj(self, lt_objs, pageNum, contents):
        # loop over the object list
        for obj in lt_objs:
            # if it's text, add the text and its position, fontname and page number into the dict contents
            if isinstance(obj, pdfminer.layout.LTTextLine):
                text = obj.get_text().replace('\n','')
                fontname = self.parse_obj(obj._objs, pageNum, contents)
                if text in contents:
                    contents[text].append((obj.bbox[0], obj.bbox[1], fontname, pageNum)) #obj.bbox[0], obj.bbox[1] are the coordination of the text
                else:
                    contents[text] = [(obj.bbox[0], obj.bbox[1], fontname, pageNum)]
            # if it's the object of font, return font name
            if isinstance(obj, pdfminer.layout.LTChar):
                return obj.fontname
            
            # if it's a textbox, recurse
            if isinstance(obj, pdfminer.layout.LTTextBoxHorizontal):
                self.parse_obj(obj._objs, pageNum, contents)

            # if it's a container, recurse
            elif isinstance(obj, pdfminer.layout.LTFigure):
                self.parse_obj(obj._objs, pageNum, contents)

    def parsepdf(self, filename, startpage, endpage):

        # Open a PDF file.
        fp = open(filename, 'rb')

        # Create a PDF parser object associated with the file object.
        parser = PDFParser(fp)

        # Create a PDF document object that stores the document structure.
        document = PDFDocument(parser)

        # Check if the document allows text extraction. If not, abort.
        if not document.is_extractable:
            raise PDFTextExtractionNotAllowed

        # Create a PDF resource manager object that stores shared resources.
        rsrcmgr = PDFResourceManager()

        # Create a PDF device object.
        device = PDFDevice(rsrcmgr)

        # BEGIN LAYOUT ANALYSIS
        # Set parameters for analysis.
        laparams = LAParams()

        # Create a PDF page aggregator object.
        device = PDFPageAggregator(rsrcmgr, laparams=laparams)

        # Create a PDF interpreter object.
        interpreter = PDFPageInterpreter(rsrcmgr, device)

        contents = {}
        i = 0
        # loop over all pages in the document
        for page in PDFPage.create_pages(document):
            if i >= startpage-1 and i <= endpage-1:
                # read the page into a layout object
                interpreter.process_page(page)
                layout = device.get_result()

                # extract text from this object
                self.parse_obj(layout._objs, i, contents)
            i += 1
        return contents

# %% [markdown]
# # Select file and directory

# %%
#from Tkinter import *
#import tkFileDialog
from tkinter import *
import tkinter.filedialog

def select_file(title = 'Select the file'):
    win = Tk()
    win.title(title)
    var = StringVar()
    w = Label(win, text="File Path:")
    e = Entry(win, textvariable=var)
    b = Button(win, text="Browse",command=lambda:var.set(tkinter.filedialog.askopenfilename()))
    w.pack(side=LEFT)
    e.pack(side=LEFT)
    b.pack(side=LEFT)
    win.mainloop()
    return var.get()

def select_dir(title = 'Select the direnctory'):
    win = Tk()
    win.title(title)
    var = StringVar()

    w = Label(win, text="File Path:")
    e = Entry(win, textvariable=var)
    b = Button(win, text="Browse",command=lambda:var.set(tkinter.filedialog.askdirectory()))
    w.pack(side=LEFT)
    e.pack(side=LEFT)
    b.pack(side=LEFT)
    win.mainloop()

    return var.get()+'/'

# %%
path1 = select_file('Select the PDF file') 
#path2 = select_dir('Select the output file\'s direnctory')

# %% [markdown]
# # select pages

# %%
# The page number start from 1, not 0

#import Tkinter   
#import tkSimpleDialog    <- for python 2.7
import tkinter
import tkinter.simpledialog

def select_pages(title = 'Select Pages'):
    #root = Tkinter.Tk()
    root = tkinter.Tk()
    root.title(title)
    var1 = tkinter.StringVar()
    var2 = tkinter.StringVar()
    #b1 = Button(root, text="Select start page",command=lambda:var1.set(tkSimpleDialog.askinteger("Select start page", "enter page number", parent = root)))
    #b2 = Button(root, text="Select end page",command=lambda:var2.set(tkSimpleDialog.askinteger("Select end page", "enter page number", parent = root)))
    b1 = tkinter.Button(root, text="Select start page",command=lambda:var1.set(tkinter.simpledialog.askinteger("Select start page", "enter page number", parent = root)))
    b2 = tkinter.Button(root, text="Select end page",command=lambda:var2.set(tkinter.simpledialog.askinteger("Select end page", "enter page number", parent = root)))
    b1.grid(column = 0, row = 0)
    b2.grid(column = 1, row = 0)
    #var = tkSimpleDialog.askstring("Select Pates", "enter your name", parent = root)
    root.mainloop()
    start_page = var1.get()
    end_page = var2.get()
    return  (start_page, end_page)

# %%
# get some sample pages for pairing the postions of categories and their contents
record_pos = pdfPositionHandling()
(start_page, end_page) = select_pages(title = 'Select Sample Pages')
sample_page_contents = record_pos.parsepdf(path1, startpage=int(start_page), endpage=int(end_page))

# %%
(start_page, end_page) = select_pages()
contents = record_pos.parsepdf(path1, int(start_page), int(end_page))
#for text in contents:
    #print(text)
    #print(contents[text])

# %% [markdown]
# # Select categories

# %%
# get filted contents
filted_contents = {}
threshold = (int(end_page) - int(start_page) + 1) * FREQUENCY_THRESHOLD
for text in contents:
    #if len(contents[text]) > 20: 
    if len(contents[text]) > threshold:
        filted_contents[text] = contents[text]
        #print(text + ' ' +str(len(filted_contents[text])))

# %%
#from Tkinter import *
#import Tkinter as tk
import tkinter as tk

class SelectWin(tk.Frame):
     
    def __init__(self, root, *args, **kwargs):
        tk.Frame.__init__(self, root, *args, **kwargs)
        self.root = root
        self.vsb = tk.Scrollbar(self, orient="vertical")
        self.text = tk.Text(self, width=40, height=20, yscrollcommand=self.vsb.set)
        self.vsb.config(command=self.text.yview)
        self.vsb.pack(side="right", fill="y")
        self.text.pack(side="left", fill="both", expand=True)
        
        self.temp_contents = {}

        var = []
        c = []
        for i, cat in enumerate(sorted(filted_contents)):
            c.append(cat)
            v = tk.BooleanVar()
            var.append(v)
            cb = tk.Checkbutton(self, text="#%s" % cat, variable=var[i])
            self.text.window_create("end", window=cb)
            self.text.insert("end", "\n") # to force one checkbox in one line
                      
        def var_states():
            for i,v in enumerate(var):
                if v.get():
                    #print(c[i])
                    self.temp_contents[c[i]] = filted_contents[c[i]]
        tk.Button(root, text='Select', command=var_states).pack()

# %%
root = tk.Tk()
root.title('selecte categories')
win = SelectWin(root)
win.pack(side="top", fill="both", expand=True)
root.mainloop()

filted_contents = win.temp_contents

# %% [markdown]
# # Search neighbors

# %%
from itertools import product
neighbors = {}
    
for line1, line2 in product(filted_contents, sample_page_contents):
    key = line1
    value = line2
    if not key in neighbors:
        neighbors[key] = []
    if(line1 != line2 and line1 in sample_page_contents
       and abs(int(sample_page_contents[line1][0][0])-int(sample_page_contents[line2][0][0]))<HORIZONTAL_DISTANCE    ###set at beginning
       and abs(int(sample_page_contents[line1][0][1])-int(sample_page_contents[line2][0][1]))<VERTICAL_DISTANCE): ###set at beginning
        neighbors[key].append(value)

# %%
#import Tkinter as tk
#import ttk
import tkinter as tk
import tkinter.ttk

win = tk.Tk()
win.title("Pairing")   
 
tkinter.ttk.Label(win, text="Select category:").grid(column=0, row=0)   
pos_or_area = StringVar()
def select():  
    if pos_or_area.get() == 'area':
        ls = list(neighbors.keys())   
        ls += ['#END']
        dropdown2['values'] = ls
    else:
        ls = neighbors[category.get()]
        dropdown2['values'] = ls
    dropdown2.current()    

R1 = tkinter.ttk.Radiobutton(win, text="find by position", variable=pos_or_area, value='pos', command=select)
R1.grid(column = 2, row = 0)
R2 = tkinter.ttk.Radiobutton(win, text="find by area", variable=pos_or_area, value='area', command=select)
R2.grid(column = 3, row = 0)
    
pairs = {}
def bind():   
    #key = contents[category.get()]
    #new_value = contents[content.get()]
    key = category.get()
    if not key in pairs:
        pairs[key] = set([])
    
    if pos_or_area.get()=='pos':
        a = sample_page_contents[category.get()][0]
        b = sample_page_contents[content.get()][0]
        c = (b[0]-a[0], b[1]-a[1], b[2], pos_or_area.get())
        pairs[key].add(c)
    else:
        c = (content.get(), 'area') 
        pairs[key].add(c)
        
    dropdown2.current()
    
# creat a drop-down list
category = tk.StringVar()
dropdown1 = tkinter.ttk.Combobox(win, width=40, height=20, textvariable=category)
dropdown1['values'] = list(neighbors.keys())   
dropdown1.grid(column=0, row=1)      
#dropdown1.current(0)     


# create another drop-down list
content = tk.StringVar()
dropdown2 = tkinter.ttk.Combobox(win, width=40, textvariable=content)    
dropdown2.grid(column=2, row=1)  
 

# bind button
action = tkinter.ttk.Button(win, text="Bind", command=bind)
action.grid(column=4, row=1) 

win.mainloop()      # window

# %%
#body_start = 660    # the starting position of the body part

# %%
def find_content_by_pos(content_map, content_pos):
    content = ()
    for c in content_map:
        m = 1 #### maximal error allowed#########################
        for pos in content_map[c]:
            error = abs(content_pos[0]-pos[0]) + abs(content_pos[1]-pos[1])
            #print error
            if error < m and content_pos[-1]==pos[-1]:
                content = (c, pos[0], pos[1], pos[2])
                break
    return content
#todo zhongzhu cover 2 or n pages
def find_content_by_area(content_map, end_cat, start_pos):
    content = {}
    end_pos = (0,0,start_pos[-1]);
    
    if end_cat in content_map:
        for pos in content_map[end_cat]:
            if pos[-1] == start_pos[-1]:
                end_pos = pos
                break
    for c in content_map:
        for pos in content_map[c]:
            #print(pos, start_pos,end_pos)
            if pos[-1]==start_pos[-1] and pos[1] > end_pos[1] and pos[1] < start_pos[1]:
                #content.append((c, pos[0], pos[1], pos[2])) 
                
                if pos[1] in content:
                    content[pos[1]].append((c, pos[0], pos[1], pos[2])) 
                else:
                    content[pos[1]] = [(c, pos[0], pos[1], pos[2])]
                    
    if end_pos[1] == 0 and end_cat in content_map:
        for pos in content_map[end_cat]:
            if pos[-1] == start_pos[-1]+1:
                end_pos = pos
                break
        for c in content_map:
            for pos in content_map[c]:
                #print(pos, start_pos,end_pos)
                if pos[-1]==start_pos[-1]+1 and pos[1] > end_pos[1] and pos[1] < BODY_START_POS:
                    #content.append((c, pos[0], pos[1], pos[2])) 
                    if pos[1]-1000 in content:
                        content[pos[1]-1000].append((c, pos[0], pos[1], pos[2])) 
                    else:
                        content[pos[1]-1000] = [(c, pos[0], pos[1], pos[2])]
    return content
    
data = {}
content_map = contents

for cat in pairs:
    #print(pairs[cat])
    pages = {}
    for pos in content_map[cat]:
        content = []
        for shift in pairs[cat]:
            if shift[-1] == 'pos':
                content_pos = (pos[0]+shift[0], pos[1]+shift[1], pos[2], pos[-1])
                content.append(find_content_by_pos(content_map, content_pos))
            elif shift[-1] == 'area':
                end_cat = shift[0]
                #if end_cat == '#END':
                    #continue #more?
                content = find_content_by_area(content_map, end_cat, pos)
        pages[pos[-1]] = content
    data[cat] = pages

# %%
print(data)
# Out:
# {'DATE': {0: [('01 Nov 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 1: [()], 2: [('02 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 3: [()], 4: [('03 Nov 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 5: [()], 6: [('04 Nov 2004 - Thursday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 7: [()], 8: [('05 Nov 2004 - Friday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 9: [()], 10: [()], 11: [()], 12: [('09 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 13: [()], 14: [('10 Nov 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 15: [()], 16: [('11 Nov 2004 - Thursday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 17: [()], 18: [('12 Nov 2004 - Friday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 19: [()], 20: [('15 Nov 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 21: [()], 22: [('16 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 23: [()], 24: [('17 Nov 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 25: [()], 26: [('18 Nov 2004 - Thursday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 27: [()], 28: [('19 Nov 2004 - Friday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 29: [()], 30: [('22 Nov 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 31: [()], 32: [('23 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 33: [()], 34: [('24 Nov 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 35: [()], 36: [('29 Nov 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 37: [()], 38: [('30 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 39: [()], 40: [('01 Dec 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 41: [()], 42: [('02 Dec 2004 - Thursday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 43: [()], 44: [('03 Dec 2004 - Friday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 45: [()], 46: [('06 Dec 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 47: [()], 48: [('07 Dec 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')], 49: [()]}, 'REPORT NUMBER': {0: [('91', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 1: [('91', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 2: [('92', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 3: [('92', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 4: [('93', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 5: [('93', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 6: [('94', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 7: [('94', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 8: [('95', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 9: [('95', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 10: [('96', 424.44, 718.1221125, 'CNLNGN+ArialMT')], 11: [('98', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 12: [('99', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 13: [('99', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 14: [('100', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 15: [('100', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 16: [('101', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 17: [('101', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 18: [('102', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 19: [('102', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 20: [('105', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 21: [('105', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 22: [('106', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 23: [('106', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 24: [('107', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 25: [('107', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 26: [('108', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 27: [('108', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 28: [('109', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 29: [('109', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 30: [('112', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 31: [('112', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 32: [('113', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 33: [('113', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 34: [('114', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 35: [('114', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 36: [('119', 424.14, 718.1835895, 'CNLNGN+ArialMT')], 37: [('119', 4 ...

# %% [markdown]
# # Save data

# %%
import pickle
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
#save data
#save_obj(data, 'seatle_all_for_mysql')
#save_obj(pairs, 'paris_seatle_all_for_mysql')
#save_obj(filted_contents, 'filted_all_for_mysql')

# %%
#pk_data = load_obj('seatle_all_for_mysql')
#pairs = load_obj('paris_seatle_all_for_mysql')

# %% [markdown]
# # database

# %%
#pk_data = load_obj('seatle_all_for_mysql')
#data = pk_data #load data

# %%
# dict for page number and REPORT NUMBER
report_num = {}
for i in data['REPORT NUMBER']: ###hardcoded. could be implemented by user interface
    report_num[i] = data['REPORT NUMBER'][i][0][0];
print(report_num)
# Out:
# {0: '91', 1: '91', 2: '92', 3: '92', 4: '93', 5: '93', 6: '94', 7: '94', 8: '95', 9: '95', 10: '96', 11: '98', 12: '99', 13: '99', 14: '100', 15: '100', 16: '101', 17: '101', 18: '102', 19: '102', 20: '105', 21: '105', 22: '106', 23: '106', 24: '107', 25: '107', 26: '108', 27: '108', 28: '109', 29: '109', 30: '112', 31: '112', 32: '113', 33: '113', 34: '114', 35: '114', 36: '119', 37: '119', 38: '120', 39: '120', 40: '121', 41: '121', 42: '122', 43: '122', 44: '123', 45: '123', 46: '126', 47: '126', 48: '127', 49: '127'}

# %%
#group pages by report number
new_data = {}
for cat, content in data.items():
    new_content = {}
    #print(cat)
    #print(content)
    for page_num in content:
        #print(type(page_num))
        p = page_num
        while p >= 0:
            if p in report_num and not report_num[p] in new_content:
                new_content[report_num[p]] = content[page_num]
                break
            p -= 1
    new_data[cat] = new_content
#print(new_data['DATE'])
#save_obj(new_data, 'seatle_all_repnum_for_mysql')

# %%
data = new_data

# %%
data
# Out:
# {'DATE': {'100': [('10 Nov 2004 - Wednesday',
#     424.14,
#     694.9015785,
#     'CNLNGN+ArialMT')],
#   '101': [('11 Nov 2004 - Thursday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '102': [('12 Nov 2004 - Friday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '105': [('15 Nov 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '106': [('16 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '107': [('17 Nov 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '108': [('18 Nov 2004 - Thursday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '109': [('19 Nov 2004 - Friday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '112': [('22 Nov 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '113': [('23 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '114': [('24 Nov 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '119': [('29 Nov 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '120': [('30 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '121': [('01 Dec 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '122': [('02 Dec 2004 - Thursday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '123': [('03 Dec 2004 - Friday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '126': [('06 Dec 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '127': [('07 Dec 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '91': [('01 Nov 2004 - Monday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '92': [('02 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '93': [('03 Nov 2004 - Wednesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '94': [('04 Nov 2004 - Thursday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '95': [('05 Nov 2004 - Friday', 424.14, 694.9015785, 'CNLNGN+ArialMT')],
#   '96': [()],
#   '98': [()],
#   '99': [('09 Nov 2004 - Tuesday', 424.14, 694.9015785, 'CNLNGN+ArialMT')]},
#  'LABOR HOURS': {'100': {127.299326: [('Total hours w orked to date: 45.0',
#      95.5771992,
#      127.299326,
#      'CNLNGN+ArialMT')],
#    130.84358949999998: [('Total',
#      417.78,
#      130.84358949999998,
#      'CNLNGN+ArialMT'),
#     ('3.0', 464.33746709999997, 130.84358949999998, 'CNLNGN+ArialMT'),
#     ('30.0', 527.755826, 130.84358949999998, 'CNLNGN+ArialMT')],
#    140.74059849999998: [('OPERATING ENGINEER',
#      197.09978628999994,
#      140.74059849999998,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement',
#      95.57999999999993,
#      140.74059849999998,
#      'CNLNGN+ArialMT'),
#     ('1.0', 464.33251219999994, 140.74059849999998, 'CNLNGN+ArialMT'),
#     ('10.0', 527.7508710999999, 140.74059849999998, 'CNLNGN+ArialMT')],
#    151.3035895: [('Asbestos Abatement', 95.58, 151.3035895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 151.3035895, 'CNLNGN+ArialMT'),
#     ('2.0', 464.3247565, 151.3035895, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7431154, 151.3035895, 'CNLNGN+ArialMT')],
#    164.68559100000002: [('Labor Classification',
#      197.10009846000003,
#      164.68559100000002,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 164.68559100000002, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 164.68559100000002, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 164.68559100000002, 'CNLNGN+ArialMT')],
#    174.58160900000001: [('Number of',
#      441.0649488,
#      174.58160900000001,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 174.58160900000001, 'CNLNGN+ArialMT')],
#    177.823408: [('The following labor hours were Reported today:',
#      85.6832634,
#      177.823408,
#      'Arial-BoldMT')]},
#   '101': {135.759326: [('Total hours w orked to date: 75.0',
#      95.5771992,
#      135.759326,
#      'CNLNGN+ArialMT')],
#    139.3035895: [('Total', 417.78, 139.3035895, 'CNLNGN+ArialMT'),
#     ('3.0', 464.33746709999997, 139.3035895, 'CNLNGN+ArialMT'),
#     ('30.0', 527.755826, 139.3035895, 'CNLNGN+ArialMT')],
#    149.2006985: [('OPERATING ENGINEER',
#      197.09978628999994,
#      149.2006985,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 149.2006985, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 149.2006985, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 149.2006985, 'CNLNGN+ArialMT')],
#    159.7636895: [('Asbestos Abatement', 95.58, 159.7636895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 159.7636895, 'CNLNGN+ArialMT'),
#     ('1.0', 464.3247565, 159.7636895, 'CNLNGN+ArialMT'),
#     ('10.0', 527.7431154, 159.7636895, 'CNLNGN+ArialMT')],
#    173.14549100000002: [('Labor Classification',
#      197.10009846000003,
#      173.14549100000002,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 173.14549100000002, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 173.14549100000002, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 173.14549100000002, 'CNLNGN+ArialMT')],
#    183.04150900000002: [('Number of',
#      441.0649488,
#      183.04150900000002,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 183.04150900000002, 'CNLNGN+ArialMT')],
#    186.283308: [('The following labor hours were Reported today:',
#      85.6832634,
#      186.283308,
#      'Arial-BoldMT')]},
#   '102': {626.5062734999999: [('Total hours w orked to date: 75.0',
#      95.5795366,
#      626.5062734999999,
#      'CNLNGN+ArialMT')],
#    639.6440905: [('No labor hours were Reported today',
#      85.6832634,
#      639.6440905,
#      'Arial-BoldMT')]},
#   '105': {579.2813699999999: [('Total hours w orked to date: 119.5',
#      95.5771992,
#      579.2813699999999,
#      'CNLNGN+ArialMT')],
#    582.7635895: [('Total', 417.78, 582.7635895, 'CNLNGN+ArialMT'),
#     ('5.0', 464.33746709999997, 582.7635895, 'CNLNGN+ArialMT'),
#     ('44.5', 527.755826, 582.7635895, 'CNLNGN+ArialMT')],
#    592.6645804999999: [('2.0',
#      464.3325122,
#      592.6645804999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.57224429999997,
#      592.6645804999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.07884589999998,
#      592.6645804999999,
#      'CNLNGN+ArialMT'),
#     ('21.0', 527.7508711, 592.6645804999999, 'CNLNGN+ArialMT')],
#    603.2275715: [('OPERATING ENGINEER',
#      197.09203058999998,
#      603.2275715,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57224429999997, 603.2275715, 'CNLNGN+ArialMT'),
#     ('2.0', 464.3247565, 603.2275715, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7431154, 603.2275715, 'CNLNGN+ArialMT')],
#    613.1235895: [('Asbestos Abatement', 95.58, 613.1235895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 613.1235895, 'CNLNGN+ArialMT'),
#     ('1.0', 464.3247565, 613.1235895, 'CNLNGN+ArialMT'),
#     ('3.5', 532.0009947, 613.1235895, 'CNLNGN+ArialMT')],
#    626.498518: [('Labor Classification',
#      197.10009846000003,
#      626.498518,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 626.498518, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 626.498518, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 626.498518, 'CNLNGN+ArialMT')],
#    637.061509: [('Number of', 441.0649488, 637.061509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 637.061509, 'CNLNGN+ArialMT')],
#    639.6440905: [('The following labor hours were Reported today:',
#      85.6832634,
#      639.6440905,
#      'Arial-BoldMT')]},
#   '106': {494.68137: [('Total hours w orked to date: 197.5',
#      95.5771992,
#      494.68137,
#      'CNLNGN+ArialMT')],
#    498.1635895: [('Total', 417.78, 498.1635895, 'CNLNGN+ArialMT'),
#     ('8.0', 464.33746709999997, 498.1635895, 'CNLNGN+ArialMT'),
#     ('78.0', 527.755826, 498.1635895, 'CNLNGN+ArialMT')],
#    508.0628509999999: [('2.0',
#      464.3402679000001,
#      508.0628509999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.58000000000004,
#      508.0628509999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      508.0628509999999,
#      'CNLNGN+ArialMT'),
#     ('21.0', 527.7586268000001, 508.0628509999999, 'CNLNGN+ArialMT')],
#    518.6258419999999: [('OPERATING ENGINEER',
#      197.09435729999993,
#      518.6258419999999,
#      'CNLNGN+ArialMT'),
#     ('3.0', 464.34026789999996, 518.6258419999999, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 518.6258419999999, 'CNLNGN+ArialMT'),
#     ('27.0', 527.7586268, 518.6258419999999, 'CNLNGN+ArialMT')],
#    528.52186: [('OPERATING ENGINEER',
#      197.09978628999994,
#      528.52186,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 528.52186, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 528.52186, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 528.52186, 'CNLNGN+ArialMT')],
#    538.3635895: [('Asbestos Abatement', 95.58, 538.3635895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 538.3635895, 'CNLNGN+ArialMT'),
#     ('1.0', 464.3247565, 538.3635895, 'CNLNGN+ArialMT'),
#     ('10.0', 527.7431154, 538.3635895, 'CNLNGN+ArialMT')],
#    552.465591: [('Labor Classification',
#      197.10009846000003,
#      552.465591,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 552.465591, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 552.465591, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 552.465591, 'CNLNGN+ArialMT')],
#    562.361609: [('Number of', 441.0649488, 562.361609, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 562.361609, 'CNLNGN+ArialMT')],
#    565.6034080000001: [('The following labor hours were Reported today:',
#      85.6832634,
#      565.6034080000001,
#      'Arial-BoldMT')]},
#   '107': {569.3805875: [('Total hours w orked to date: 269.5',
#      95.5771992,
#      569.3805875,
#      'CNLNGN+ArialMT')],
#    572.2035895: [('Total', 417.78, 572.2035895, 'CNLNGN+ArialMT'),
#     ('8.0', 464.33746709999997, 572.2035895, 'CNLNGN+ArialMT'),
#     ('72.0', 527.755826, 572.2035895, 'CNLNGN+ArialMT')],
#    582.7685624999999: [('2.0',
#      464.3402679000001,
#      582.7685624999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.58000000000004,
#      582.7685624999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      582.7685624999999,
#      'CNLNGN+ArialMT'),
#     ('21.0', 527.7586268000001, 582.7685624999999, 'CNLNGN+ArialMT')],
#    592.6645804999999: [('OPERATING ENGINEER',
#      197.09435729999993,
#      592.6645804999999,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.34026789999996, 592.6645804999999, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 592.6645804999999, 'CNLNGN+ArialMT'),
#     ('11.0', 527.7586268, 592.6645804999999, 'CNLNGN+ArialMT')],
#    603.2275715: [('OPERATING ENGINEER',
#      197.09978628999994,
#      603.2275715,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 603.2275715, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 603.2275715, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 603.2275715, 'CNLNGN+ArialMT')],
#    613.1235895: [('Asbestos Abatement', 95.58, 613.1235895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 613.1235895, 'CNLNGN+ArialMT'),
#     ('2.0', 464.3247565, 613.1235895, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7431154, 613.1235895, 'CNLNGN+ArialMT')],
#    626.498518: [('Labor Classification',
#      197.10009846000003,
#      626.498518,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 626.498518, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 626.498518, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 626.498518, 'CNLNGN+ArialMT')],
#    637.061509: [('Number of', 441.0649488, 637.061509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 637.061509, 'CNLNGN+ArialMT')],
#    639.6440905: [('The following labor hours were Reported today:',
#      85.6832634,
#      639.6440905,
#      'Arial-BoldMT')]},
#   '108': {494.68137: [('Total hours w orked to date: 371.5',
#      95.5771992,
#      494.68137,
#      'CNLNGN+ArialMT')],
#    498.1635895: [('Total', 417.78, 498.1635895, 'CNLNGN+ArialMT'),
#     ('10.0', 460.07958779999996, 498.1635895, 'CNLNGN+ArialMT'),
#     ('102.0', 523.5522366, 498.1635895, 'CNLNGN+ArialMT')],
#    508.0628509999999: [('2.0',
#      464.3402679000001,
#      508.0628509999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.58000000000004,
#      508.0628509999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      508.0628509999999,
#      'CNLNGN+ArialMT'),
#     ('21.0', 527.7586268000001, 508.0628509999999, 'CNLNGN+ArialMT')],
#    518.6258419999999: [('OPERATING ENGINEER',
#      197.09435729999993,
#      518.6258419999999,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.34026789999996, 518.6258419999999, 'CNLNGN+ArialMT'),
#     ('21.0', 527.7586268, 518.6258419999999, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 518.6258419999999, 'CNLNGN+ArialMT')],
#    528.52186: [('OPERATING ENGINEER',
#      197.09978628999994,
#      528.52186,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 528.52186, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 528.52186, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 528.52186, 'CNLNGN+ArialMT')],
#    538.3635895: [('Asbestos Abatement', 95.58, 538.3635895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 538.3635895, 'CNLNGN+ArialMT'),
#     ('4.0', 464.3247565, 538.3635895, 'CNLNGN+ArialMT'),
#     ('40.0', 527.7431154, 538.3635895, 'CNLNGN+ArialMT')],
#    552.465591: [('Labor Classification',
#      197.10009846000003,
#      552.465591,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 552.465591, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 552.465591, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 552.465591, 'CNLNGN+ArialMT')],
#    562.361609: [('Number of', 441.0649488, 562.361609, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 562.361609, 'CNLNGN+ArialMT')],
#    565.6034080000001: [('The following labor hours were Reported today:',
#      85.6832634,
#      565.6034080000001,
#      'Arial-BoldMT')]},
#   '109': {599.74137: [('Total hours w orked to date: 391.5',
#      95.5771992,
#      599.74137,
#      'CNLNGN+ArialMT')],
#    603.2235895: [('Total', 417.78, 603.2235895, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33746709999997, 603.2235895, 'CNLNGN+ArialMT'),
#     ('20.0', 527.755826, 603.2235895, 'CNLNGN+ArialMT')],
#    613.1235895: [('OPERATING ENGINEER',
#      197.0943573,
#      613.1235895,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.3402679, 613.1235895, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7586268, 613.1235895, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.58, 613.1235895, 'CNLNGN+ArialMT')],
#    626.498518: [('Labor Classification',
#      197.10009846000003,
#      626.498518,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 626.498518, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 626.498518, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 626.498518, 'CNLNGN+ArialMT')],
#    637.061509: [('Number of', 441.0649488, 637.061509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 637.061509, 'CNLNGN+ArialMT')],
#    639.6440905: [('The following labor hours were Reported today:',
#      85.6832634,
#      639.6440905,
#      'Arial-BoldMT')]},
#   '112': {558.8193259999999: [('Total hours w orked to date: 443.0',
#      95.5771992,
#      558.8193259999999,
#      'CNLNGN+ArialMT')],
#    562.3635895: [('Total', 417.78, 562.3635895, 'CNLNGN+ArialMT'),
#     ('6.0', 464.33746709999997, 562.3635895, 'CNLNGN+ArialMT'),
#     ('51.5', 527.755826, 562.3635895, 'CNLNGN+ArialMT')],
#    572.2005985: [('2.0', 464.3402679000001, 572.2005985, 'CNLNGN+ArialMT'),
#     ("Roman's Trucking", 95.58000000000004, 572.2005985, 'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      572.2005985,
#      'CNLNGN+ArialMT'),
#     ('12.5', 527.7586268000001, 572.2005985, 'CNLNGN+ArialMT')],
#    582.7635895: [('OPERATING ENGINEER',
#      197.0943573,
#      582.7635895,
#      'CNLNGN+ArialMT'),
#     ('Patterson', 95.58, 582.7635895, 'CNLNGN+ArialMT'),
#     ('4.0', 464.3402679, 582.7635895, 'CNLNGN+ArialMT'),
#     ('39.0', 527.7586268, 582.7635895, 'CNLNGN+ArialMT')],
#    596.207535: [('Labor Classification',
#      197.10009846000003,
#      596.207535,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 596.207535, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 596.207535, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 596.207535, 'CNLNGN+ArialMT')],
#    606.0492645: [('Number of', 441.0649488, 606.0492645, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 606.0492645, 'CNLNGN+ArialMT')],
#    609.345352: [('The following labor hours were Reported today:',
#      85.6832634,
#      609.345352,
#      'Arial-BoldMT')]},
#   '113': {569.3805875: [('Total hours w orked to date: 552.5',
#      95.5771992,
#      569.3805875,
#      'CNLNGN+ArialMT')],
#    572.2035895: [('Total', 417.78, 572.2035895, 'CNLNGN+ArialMT'),
#     ('11.0', 460.07958779999996, 572.2035895, 'CNLNGN+ArialMT'),
#     ('109.5', 523.5522366, 572.2035895, 'CNLNGN+ArialMT')],
#    582.7685624999999: [('1.0',
#      464.3402679000001,
#      582.7685624999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.58000000000004,
#      582.7685624999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      582.7685624999999,
#      'CNLNGN+ArialMT'),
#     ('10.5', 527.7586268000001, 582.7685624999999, 'CNLNGN+ArialMT')],
#    592.6645804999999: [('OPERATING ENGINEER',
#      197.09435729999993,
#      592.6645804999999,
#      'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 592.6645804999999, 'CNLNGN+ArialMT'),
#     ('4.0', 464.34026789999996, 592.6645804999999, 'CNLNGN+ArialMT'),
#     ('39.0', 527.7586268, 592.6645804999999, 'CNLNGN+ArialMT')],
#    603.2275715: [('OPERATING ENGINEER',
#      197.09978628999994,
#      603.2275715,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 603.2275715, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 603.2275715, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 603.2275715, 'CNLNGN+ArialMT')],
#    613.1235895: [('Asbestos Abatement', 95.58, 613.1235895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 613.1235895, 'CNLNGN+ArialMT'),
#     ('4.0', 464.3247565, 613.1235895, 'CNLNGN+ArialMT'),
#     ('40.0', 527.7431154, 613.1235895, 'CNLNGN+ArialMT')],
#    626.498518: [('Labor Classification',
#      197.10009846000003,
#      626.498518,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 626.498518, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 626.498518, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 626.498518, 'CNLNGN+ArialMT')],
#    637.061509: [('Number of', 441.0649488, 637.061509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 637.061509, 'CNLNGN+ArialMT')],
#    639.6440905: [('The following labor hours were Reported today:',
#      85.6832634,
#      639.6440905,
#      'Arial-BoldMT')]},
#   '114': {548.919326: [('Total hours w orked to date: 606.5',
#      95.5771992,
#      548.919326,
#      'CNLNGN+ArialMT')],
#    552.4635895: [('Total', 417.78, 552.4635895, 'CNLNGN+ArialMT'),
#     ('7.0', 464.33746709999997, 552.4635895, 'CNLNGN+ArialMT'),
#     ('54.0', 527.755826, 552.4635895, 'CNLNGN+ArialMT')],
#    562.3588689999999: [('OPERATING ENGINEER',
#      197.09435729999993,
#      562.3588689999999,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.34026789999996, 562.3588689999999, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 562.3588689999999, 'CNLNGN+ArialMT'),
#     ('28.0', 527.7586268, 562.3588689999999, 'CNLNGN+ArialMT')],
#    572.2005985: [('OPERATING ENGINEER',
#      197.07031462999993,
#      572.2005985,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 572.2005985, 'CNLNGN+ArialMT'),
#     ('1.0', 464.33251219999994, 572.2005985, 'CNLNGN+ArialMT'),
#     ('6.0', 532.0087503999999, 572.2005985, 'CNLNGN+ArialMT')],
#    582.7635895: [('Asbestos Abatement', 95.58, 582.7635895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 582.7635895, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7431154, 582.7635895, 'CNLNGN+ArialMT'),
#     ('4.0', 464.3247565, 582.7635895, 'CNLNGN+ArialMT')],
#    596.207535: [('Labor Classification',
#      197.10009846000003,
#      596.207535,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 596.207535, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 596.207535, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 596.207535, 'CNLNGN+ArialMT')],
#    606.0492645: [('Number of', 441.0649488, 606.0492645, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 606.0492645, 'CNLNGN+ArialMT')],
#    609.345352: [('The following labor hours were Reported today:',
#      85.6832634,
#      609.345352,
#      'Arial-BoldMT')]},
#   '119': {521.4394259999999: [('Total hours w orked to date: 654.5',
#      95.5771992,
#      521.4394259999999,
#      'CNLNGN+ArialMT')],
#    524.9836895: [('Total', 417.78, 524.9836895, 'CNLNGN+ArialMT'),
#     ('5.0', 464.33746709999997, 524.9836895, 'CNLNGN+ArialMT'),
#     ('48.0', 527.755826, 524.9836895, 'CNLNGN+ArialMT')],
#    535.5428509999999: [('OPERATING ENGINEER',
#      197.09435729999998,
#      535.5428509999999,
#      'CNLNGN+ArialMT'),
#     ('1.0', 464.34026789999996, 535.5428509999999, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999998, 535.5428509999999, 'CNLNGN+ArialMT'),
#     ('9.0', 532.0165061, 535.5428509999999, 'CNLNGN+ArialMT')],
#    545.438869: [('1.0', 464.34026789999996, 545.438869, 'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.09435729999993,
#      545.438869,
#      'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 545.438869, 'CNLNGN+ArialMT'),
#     ('9.0', 532.0165061, 545.438869, 'CNLNGN+ArialMT')],
#    555.2805985: [('OPERATING ENGINEER',
#      197.09978628999994,
#      555.2805985,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 555.2805985, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 555.2805985, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 555.2805985, 'CNLNGN+ArialMT')],
#    565.8435895: [('Asbestos Abatement', 95.58, 565.8435895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 565.8435895, 'CNLNGN+ArialMT'),
#     ('1.0', 464.3247565, 565.8435895, 'CNLNGN+ArialMT'),
#     ('10.0', 527.7431154, 565.8435895, 'CNLNGN+ArialMT')],
#    579.287535: [('Labor Classification',
#      197.10009846000003,
#      579.287535,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 579.287535, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 579.287535, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 579.287535, 'CNLNGN+ArialMT')],
#    589.1292645000001: [('Number of',
#      441.0649488,
#      589.1292645000001,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 589.1292645000001, 'CNLNGN+ArialMT')],
#    592.4253520000001: [('The following labor hours were Reported today:',
#      85.6832634,
#      592.4253520000001,
#      'Arial-BoldMT')]},
#   '120': {521.4394259999999: [('Total hours w orked to date: 724.5',
#      95.5771992,
#      521.4394259999999,
#      'CNLNGN+ArialMT')],
#    524.9836895: [('Total', 417.78, 524.9836895, 'CNLNGN+ArialMT'),
#     ('7.0', 464.33746709999997, 524.9836895, 'CNLNGN+ArialMT'),
#     ('70.0', 527.755826, 524.9836895, 'CNLNGN+ArialMT')],
#    535.5428509999999: [('2.0',
#      464.3402679000001,
#      535.5428509999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.58000000000004,
#      535.5428509999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      535.5428509999999,
#      'CNLNGN+ArialMT'),
#     ('21.0', 527.7586268000001, 535.5428509999999, 'CNLNGN+ArialMT')],
#    545.438869: [('OPERATING ENGINEER',
#      197.09435729999993,
#      545.438869,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.34026789999996, 545.438869, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 545.438869, 'CNLNGN+ArialMT'),
#     ('19.0', 527.7586268, 545.438869, 'CNLNGN+ArialMT')],
#    555.2805985: [('OPERATING ENGINEER',
#      197.09978628999994,
#      555.2805985,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 555.2805985, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 555.2805985, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 555.2805985, 'CNLNGN+ArialMT')],
#    565.8435895: [('Asbestos Abatement', 95.58, 565.8435895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 565.8435895, 'CNLNGN+ArialMT'),
#     ('1.0', 464.3247565, 565.8435895, 'CNLNGN+ArialMT'),
#     ('10.0', 527.7431154, 565.8435895, 'CNLNGN+ArialMT')],
#    579.287535: [('Labor Classification',
#      197.10009846000003,
#      579.287535,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 579.287535, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 579.287535, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 579.287535, 'CNLNGN+ArialMT')],
#    589.1292645000001: [('Number of',
#      441.0649488,
#      589.1292645000001,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 589.1292645000001, 'CNLNGN+ArialMT')],
#    592.4253520000001: [('The following labor hours were Reported today:',
#      85.6832634,
#      592.4253520000001,
#      'Arial-BoldMT')]},
#   '121': {511.60137: [('Total hours w orked to date: 803.5',
#      95.5771992,
#      511.60137,
#      'CNLNGN+ArialMT')],
#    515.0835895: [('Total', 417.78, 515.0835895, 'CNLNGN+ArialMT'),
#     ('8.0', 464.33746709999997, 515.0835895, 'CNLNGN+ArialMT'),
#     ('79.0', 527.755826, 515.0835895, 'CNLNGN+ArialMT')],
#    524.9798599999999: [('2.0',
#      464.3402679000001,
#      524.9798599999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.58000000000004,
#      524.9798599999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      524.9798599999999,
#      'CNLNGN+ArialMT'),
#     ('21.0', 527.7586268000001, 524.9798599999999, 'CNLNGN+ArialMT')],
#    535.5428509999999: [('OPERATING ENGINEER',
#      197.09435729999998,
#      535.5428509999999,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.34026789999996, 535.5428509999999, 'CNLNGN+ArialMT'),
#     ('18.5', 527.7586268, 535.5428509999999, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999998, 535.5428509999999, 'CNLNGN+ArialMT')],
#    545.438869: [('1.0', 464.34026789999996, 545.438869, 'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.09435729999993,
#      545.438869,
#      'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 545.438869, 'CNLNGN+ArialMT'),
#     ('9.5', 532.0165061, 545.438869, 'CNLNGN+ArialMT')],
#    555.2805985: [('OPERATING ENGINEER',
#      197.09978628999994,
#      555.2805985,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 555.2805985, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 555.2805985, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 555.2805985, 'CNLNGN+ArialMT')],
#    565.8435895: [('Asbestos Abatement', 95.58, 565.8435895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 565.8435895, 'CNLNGN+ArialMT'),
#     ('1.0', 464.3247565, 565.8435895, 'CNLNGN+ArialMT'),
#     ('10.0', 527.7431154, 565.8435895, 'CNLNGN+ArialMT')],
#    579.287535: [('Labor Classification',
#      197.10009846000003,
#      579.287535,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 579.287535, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 579.287535, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 579.287535, 'CNLNGN+ArialMT')],
#    589.1292645000001: [('Number of',
#      441.0649488,
#      589.1292645000001,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 589.1292645000001, 'CNLNGN+ArialMT')],
#    592.4253520000001: [('The following labor hours were Reported today:',
#      85.6832634,
#      592.4253520000001,
#      'Arial-BoldMT')]},
#   '122': {558.8193259999999: [('Total hours w orked to date: 864.0',
#      95.5771992,
#      558.8193259999999,
#      'CNLNGN+ArialMT')],
#    562.3635895: [('Total', 417.78, 562.3635895, 'CNLNGN+ArialMT'),
#     ('7.0', 464.33746709999997, 562.3635895, 'CNLNGN+ArialMT'),
#     ('60.5', 527.755826, 562.3635895, 'CNLNGN+ArialMT')],
#    572.2055714999999: [('2.0',
#      464.3402679,
#      572.2055714999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.57999999999998,
#      572.2055714999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.0866016,
#      572.2055714999999,
#      'CNLNGN+ArialMT'),
#     ('12.5', 527.7586268, 572.2055714999999, 'CNLNGN+ArialMT')],
#    582.7685624999999: [('OPERATING ENGINEER',
#      197.09435729999998,
#      582.7685624999999,
#      'CNLNGN+ArialMT'),
#     ('1.0', 464.34026789999996, 582.7685624999999, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999998, 582.7685624999999, 'CNLNGN+ArialMT'),
#     ('9.0', 532.0165061, 582.7685624999999, 'CNLNGN+ArialMT')],
#    592.6645804999999: [('1.0',
#      464.34026789999996,
#      592.6645804999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.09435729999993,
#      592.6645804999999,
#      'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 592.6645804999999, 'CNLNGN+ArialMT'),
#     ('9.0', 532.0165061, 592.6645804999999, 'CNLNGN+ArialMT')],
#    603.2275715: [('OPERATING ENGINEER',
#      197.09978628999994,
#      603.2275715,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 603.2275715, 'CNLNGN+ArialMT'),
#     ('1.0', 464.33251219999994, 603.2275715, 'CNLNGN+ArialMT'),
#     ('10.0', 527.7508710999999, 603.2275715, 'CNLNGN+ArialMT')],
#    613.1235895: [('Asbestos Abatement', 95.58, 613.1235895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 613.1235895, 'CNLNGN+ArialMT'),
#     ('2.0', 464.3247565, 613.1235895, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7431154, 613.1235895, 'CNLNGN+ArialMT')],
#    626.498518: [('Labor Classification',
#      197.10009846000003,
#      626.498518,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 626.498518, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 626.498518, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 626.498518, 'CNLNGN+ArialMT')],
#    637.061509: [('Number of', 441.0649488, 637.061509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 637.061509, 'CNLNGN+ArialMT')],
#    639.6440905: [('The following labor hours were Reported today:',
#      85.6832634,
#      639.6440905,
#      'Arial-BoldMT')]},
#   '123': {-369.96067400000004: [('Total hours w orked to date: 893.0',
#      95.5771992,
#      630.039326,
#      'CNLNGN+ArialMT')],
#    -366.4164105: [('Total', 417.78, 633.5835895, 'CNLNGN+ArialMT'),
#     ('5.0', 464.33746709999997, 633.5835895, 'CNLNGN+ArialMT'),
#     ('29.0', 527.755826, 633.5835895, 'CNLNGN+ArialMT')],
#    -356.5794015: [('OPERATING ENGINEER',
#      197.09435729999998,
#      643.4205985,
#      'CNLNGN+ArialMT'),
#     ('1.0', 464.34026789999996, 643.4205985, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999998, 643.4205985, 'CNLNGN+ArialMT'),
#     ('2.5', 532.0165061, 643.4205985, 'CNLNGN+ArialMT')],
#    -346.0164105: [('1.0', 464.3402679, 653.9835895, 'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1', 197.0943573, 653.9835895, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.58, 653.9835895, 'CNLNGN+ArialMT'),
#     ('2.5', 532.0165061, 653.9835895, 'CNLNGN+ArialMT')],
#    117.4635895: [('LABORERS',
#      197.08582603000002,
#      117.4635895,
#      'CNLNGN+ArialMT'),
#     ('3.0', 464.3247565, 117.4635895, 'CNLNGN+ArialMT'),
#     ('CONCRETE CRUSHER', 95.58, 117.4635895, 'CNLNGN+ArialMT'),
#     ('24.0', 527.7431154, 117.4635895, 'CNLNGN+ArialMT')],
#    130.845491: [('Labor Classification',
#      197.10009846000003,
#      130.845491,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 130.845491, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 130.845491, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 130.845491, 'CNLNGN+ArialMT')],
#    140.741509: [('Number of', 441.0649488, 140.741509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 140.741509, 'CNLNGN+ArialMT')],
#    143.983308: [('The following labor hours were Reported today:',
#      85.6832634,
#      143.983308,
#      'Arial-BoldMT')]},
#   '126': {400.1805875: [('Total hours w orked to date: 961.0',
#      95.5771992,
#      400.1805875,
#      'CNLNGN+ArialMT')],
#    403.0035895: [('Total', 417.78, 403.0035895, 'CNLNGN+ArialMT'),
#     ('7.0', 464.33746709999997, 403.0035895, 'CNLNGN+ArialMT'),
#     ('68.0', 527.755826, 403.0035895, 'CNLNGN+ArialMT')],
#    413.5685624999999: [('2.0',
#      464.3402679000001,
#      413.5685624999999,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.58000000000004,
#      413.5685624999999,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      413.5685624999999,
#      'CNLNGN+ArialMT'),
#     ('21.0', 527.7586268000001, 413.5685624999999, 'CNLNGN+ArialMT')],
#    423.46458049999995: [('OPERATING ENGINEER',
#      197.09435729999998,
#      423.46458049999995,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.34026789999996, 423.46458049999995, 'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999998, 423.46458049999995, 'CNLNGN+ArialMT'),
#     ('18.0', 527.7586268, 423.46458049999995, 'CNLNGN+ArialMT')],
#    434.02757149999996: [('1.0',
#      464.34026789999996,
#      434.02757149999996,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.09435729999993,
#      434.02757149999996,
#      'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 434.02757149999996, 'CNLNGN+ArialMT'),
#     ('9.0', 532.0165061, 434.02757149999996, 'CNLNGN+ArialMT')],
#    443.9235895: [('LABORERS',
#      197.08582603000002,
#      443.9235895,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.3247565, 443.9235895, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7431154, 443.9235895, 'CNLNGN+ArialMT'),
#     ('CONCRETE CRUSHER', 95.58, 443.9235895, 'CNLNGN+ArialMT')],
#    457.298518: [('Labor Classification',
#      197.10009846000003,
#      457.298518,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 457.298518, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 457.298518, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 457.298518, 'CNLNGN+ArialMT')],
#    467.861509: [('Number of', 441.0649488, 467.861509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 467.861509, 'CNLNGN+ArialMT')],
#    470.4440905: [('The following labor hours were Reported today:',
#      85.6832634,
#      470.4440905,
#      'Arial-BoldMT')]},
#   '127': {413.559326: [('Total hours w orked to date: 1,096.0',
#      95.5771992,
#      413.559326,
#      'CNLNGN+ArialMT')],
#    417.1035895: [('Total', 417.78, 417.1035895, 'CNLNGN+ArialMT'),
#     ('14.0', 460.07958779999996, 417.1035895, 'CNLNGN+ArialMT'),
#     ('135.0', 523.5522366, 417.1035895, 'CNLNGN+ArialMT')],
#    426.99985999999996: [('2.0',
#      464.3402679000001,
#      426.99985999999996,
#      'CNLNGN+ArialMT'),
#     ("Roman's Trucking",
#      95.58000000000004,
#      426.99985999999996,
#      'CNLNGN+ArialMT'),
#     ('TRUCK DRIVER, GROUP 1',
#      197.08660160000005,
#      426.99985999999996,
#      'CNLNGN+ArialMT'),
#     ('21.0', 527.7586268000001, 426.99985999999996, 'CNLNGN+ArialMT')],
#    436.84158949999994: [('OPERATING ENGINEER',
#      197.09435729999993,
#      436.84158949999994,
#      'CNLNGN+ArialMT'),
#     ('Patterson', 95.57999999999993, 436.84158949999994, 'CNLNGN+ArialMT'),
#     ('4.0', 464.34026789999996, 436.84158949999994, 'CNLNGN+ArialMT'),
#     ('34.0', 527.7586268, 436.84158949999994, 'CNLNGN+ArialMT')],
#    447.40458049999995: [('OPERATING ENGINEER',
#      197.08582602999994,
#      447.40458049999995,
#      'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 447.40458049999995, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 447.40458049999995, 'CNLNGN+ArialMT'),
#     ('CONCRETE CRUSHER',
#      95.57999999999993,
#      447.40458049999995,
#      'CNLNGN+ArialMT')],
#    457.3005985: [('OPERATING ENGINEER',
#      197.09978628999994,
#      457.3005985,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.57999999999993, 457.3005985, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33251219999994, 457.3005985, 'CNLNGN+ArialMT'),
#     ('20.0', 527.7508710999999, 457.3005985, 'CNLNGN+ArialMT')],
#    467.8635895: [('Asbestos Abatement', 95.58, 467.8635895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 467.8635895, 'CNLNGN+ArialMT'),
#     ('4.0', 464.3247565, 467.8635895, 'CNLNGN+ArialMT'),
#     ('40.0', 527.7431154, 467.8635895, 'CNLNGN+ArialMT')],
#    481.25324649999993: [('Labor Classification',
#      197.10009846000003,
#      481.25324649999993,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 481.25324649999993, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 481.25324649999993, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 481.25324649999993, 'CNLNGN+ArialMT')],
#    491.14926449999996: [('Number of',
#      441.0649488,
#      491.14926449999996,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 491.14926449999996, 'CNLNGN+ArialMT')],
#    494.44535199999996: [('The following labor hours were Reported today:',
#      85.6832634,
#      494.44535199999996,
#      'Arial-BoldMT')]},
#   '91': {163.30068749999998: [('0.0',
#      197.08069851999994,
#      163.30068749999998,
#      'CNLNGN+ArialMT'),
#     ('Total hours worked to date:',
#      95.5849548999999,
#      163.30068749999998,
#      'CNLNGN+ArialMT')],
#    166.12368949999998: [('0.0',
#      464.33746709999997,
#      166.12368949999998,
#      'CNLNGN+ArialMT'),
#     ('0.0', 532.0214609999999, 166.12368949999998, 'CNLNGN+ArialMT'),
#     ('Total', 417.78, 166.12368949999998, 'CNLNGN+ArialMT')],
#    176.68368949999999: [('OPERATING ENGINEER',
#      197.07031462999998,
#      176.68368949999999,
#      'CNLNGN+ArialMT'),
#     ('0.0', 464.3325122, 176.68368949999999, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0087504, 176.68368949999999, 'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.58, 176.68368949999999, 'CNLNGN+ArialMT')],
#    190.065491: [('Labor Classification',
#      197.10009846000003,
#      190.065491,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 190.065491, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 190.065491, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 190.065491, 'CNLNGN+ArialMT')],
#    199.961509: [('Number of', 441.0649488, 199.961509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 199.961509, 'CNLNGN+ArialMT')],
#    203.203308: [('The following labor hours were Reported today:',
#      85.6832634,
#      203.203308,
#      'Arial-BoldMT')]},
#   '92': {599.74137: [('Total hours w orked to date: 0.0',
#      95.5849548999999,
#      599.74137,
#      'CNLNGN+ArialMT')],
#    603.2235895: [('0.0', 464.33746709999997, 603.2235895, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0214609999999, 603.2235895, 'CNLNGN+ArialMT'),
#     ('Total', 417.78, 603.2235895, 'CNLNGN+ArialMT')],
#    613.1235895: [('OPERATING ENGINEER',
#      197.07031462999998,
#      613.1235895,
#      'CNLNGN+ArialMT'),
#     ('0.0', 464.3325122, 613.1235895, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0087504, 613.1235895, 'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.58, 613.1235895, 'CNLNGN+ArialMT')],
#    626.498518: [('Labor Classification',
#      197.10009846000003,
#      626.498518,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 626.498518, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 626.498518, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 626.498518, 'CNLNGN+ArialMT')],
#    637.061509: [('Number of', 441.0649488, 637.061509, 'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 637.061509, 'CNLNGN+ArialMT')],
#    639.6440905: [('The following labor hours were Reported today:',
#      85.6832634,
#      639.6440905,
#      'Arial-BoldMT')]},
#   '93': {146.3805875: [('Total hours w orked to date: 0.0',
#      95.5849548999999,
#      146.3805875,
#      'CNLNGN+ArialMT')],
#    149.2035895: [('0.0', 464.33746709999997, 149.2035895, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0214609999999, 149.2035895, 'CNLNGN+ArialMT'),
#     ('Total', 417.78, 149.2035895, 'CNLNGN+ArialMT')],
#    159.7636895: [('OPERATING ENGINEER',
#      197.07031462999998,
#      159.7636895,
#      'CNLNGN+ArialMT'),
#     ('0.0', 464.3325122, 159.7636895, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0087504, 159.7636895, 'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.58, 159.7636895, 'CNLNGN+ArialMT')],
#    173.14549100000002: [('Labor Classification',
#      197.10009846000003,
#      173.14549100000002,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 173.14549100000002, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 173.14549100000002, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 173.14549100000002, 'CNLNGN+ArialMT')],
#    183.04150900000002: [('Number of',
#      441.0649488,
#      183.04150900000002,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 183.04150900000002, 'CNLNGN+ArialMT')],
#    186.283308: [('The following labor hours were Reported today:',
#      85.6832634,
#      186.283308,
#      'Arial-BoldMT')]},
#   '94': {146.3805875: [('Total hours w orked to date: 0.0',
#      95.5849548999999,
#      146.3805875,
#      'CNLNGN+ArialMT')],
#    149.2035895: [('0.0', 464.33746709999997, 149.2035895, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0214609999999, 149.2035895, 'CNLNGN+ArialMT'),
#     ('Total', 417.78, 149.2035895, 'CNLNGN+ArialMT')],
#    159.7636895: [('OPERATING ENGINEER',
#      197.07031462999998,
#      159.7636895,
#      'CNLNGN+ArialMT'),
#     ('0.0', 464.3325122, 159.7636895, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0087504, 159.7636895, 'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.58, 159.7636895, 'CNLNGN+ArialMT')],
#    173.14549100000002: [('Labor Classification',
#      197.10009846000003,
#      173.14549100000002,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 173.14549100000002, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 173.14549100000002, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 173.14549100000002, 'CNLNGN+ArialMT')],
#    183.04150900000002: [('Number of',
#      441.0649488,
#      183.04150900000002,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 183.04150900000002, 'CNLNGN+ArialMT')],
#    186.283308: [('The following labor hours were Reported today:',
#      85.6832634,
#      186.283308,
#      'Arial-BoldMT')]},
#   '95': {146.3805875: [('Total hours w orked to date: 0.0',
#      95.5849548999999,
#      146.3805875,
#      'CNLNGN+ArialMT')],
#    149.2035895: [('0.0', 464.33746709999997, 149.2035895, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0214609999999, 149.2035895, 'CNLNGN+ArialMT'),
#     ('Total', 417.78, 149.2035895, 'CNLNGN+ArialMT')],
#    159.7636895: [('OPERATING ENGINEER',
#      197.07031462999998,
#      159.7636895,
#      'CNLNGN+ArialMT'),
#     ('0.0', 464.3325122, 159.7636895, 'CNLNGN+ArialMT'),
#     ('0.0', 532.0087504, 159.7636895, 'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.58, 159.7636895, 'CNLNGN+ArialMT')],
#    173.14549100000002: [('Labor Classification',
#      197.10009846000003,
#      173.14549100000002,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 173.14549100000002, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 173.14549100000002, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 173.14549100000002, 'CNLNGN+ArialMT')],
#    183.04150900000002: [('Number of',
#      441.0649488,
#      183.04150900000002,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 183.04150900000002, 'CNLNGN+ArialMT')],
#    186.283308: [('The following labor hours were Reported today:',
#      85.6832634,
#      186.283308,
#      'Arial-BoldMT')]},
#   '96': {372.3424125: [('Total hours w orked to date: 0.0',
#      95.63591109999993,
#      372.3424125,
#      'CNLNGN+ArialMT')],
#    375.8821125: [('0.0', 464.69662235, 375.8821125, 'CNLNGN+ArialMT'),
#     ('0.0', 532.4363318, 375.8821125, 'CNLNGN+ArialMT'),
#     ('Total', 418.14, 375.8821125, 'CNLNGN+ArialMT')],
#    385.72211250000004: [('OPERATING ENGINEER',
#      197.19752592999998,
#      385.72211250000004,
#      'CNLNGN+ArialMT'),
#     ('0.0', 464.68114799999995, 385.72211250000004, 'CNLNGN+ArialMT'),
#     ('0.0', 532.4169448, 385.72211250000004, 'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.64, 385.72211250000004, 'CNLNGN+ArialMT')],
#    399.88331250000005: [('Labor Classification',
#      197.23589928000004,
#      399.88331250000005,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.64315950000002, 399.88331250000005, 'CNLNGN+ArialMT'),
#     ('Employees', 441.43142855000025, 399.88331250000005, 'CNLNGN+ArialMT'),
#     ('Worked', 509.18522354000027, 399.88331250000005, 'CNLNGN+ArialMT')],
#    409.72616250000004: [('Number of',
#      441.4196906,
#      409.72616250000004,
#      'CNLNGN+ArialMT'),
#     ('Hours', 509.16409523000004, 409.72616250000004, 'CNLNGN+ArialMT')],
#    413.02522500000003: [('The following labor hours were Reported today:',
#      85.73632970000001,
#      413.02522500000003,
#      'Arial-BoldMT')]},
#   '98': {206.98559099999997: [('Total hours w orked to date: 0.0',
#      95.5795366,
#      206.98559099999997,
#      'CNLNGN+ArialMT')],
#    220.18545199999997: [('No labor hours were Reported today',
#      85.6832634,
#      220.18545199999997,
#      'Arial-BoldMT')]},
#   '99': {-360.12057400000003: [('Total hours w orked to date: 15.0',
#      95.5771992,
#      639.879426,
#      'CNLNGN+ArialMT')],
#    -356.5763105: [('Total', 417.78, 643.4236895, 'CNLNGN+ArialMT'),
#     ('2.0', 464.33746709999997, 643.4236895, 'CNLNGN+ArialMT'),
#     ('15.0', 527.755826, 643.4236895, 'CNLNGN+ArialMT')],
#    -346.0164105: [('OPERATING ENGINEER',
#      197.09978629,
#      653.9835895,
#      'CNLNGN+ArialMT'),
#     ('Asbestos Abatement', 95.58, 653.9835895, 'CNLNGN+ArialMT'),
#     ('1.0', 464.3325122, 653.9835895, 'CNLNGN+ArialMT'),
#     ('10.0', 527.7508711, 653.9835895, 'CNLNGN+ArialMT')],
#    122.3836895: [('Asbestos Abatement', 95.58, 122.3836895, 'CNLNGN+ArialMT'),
#     ('LABORERS', 197.07031462999998, 122.3836895, 'CNLNGN+ArialMT'),
#     ('1.0', 464.3247565, 122.3836895, 'CNLNGN+ArialMT'),
#     ('5.0', 532.0009947, 122.3836895, 'CNLNGN+ArialMT')],
#    135.76422949999997: [('Labor Classification',
#      197.10009846000003,
#      135.76422949999997,
#      'CNLNGN+ArialMT'),
#     ('Employer', 95.5872923, 135.76422949999997, 'CNLNGN+ArialMT'),
#     ('Employees', 441.0308237199999, 135.76422949999997, 'CNLNGN+ArialMT'),
#     ('Worked', 508.69853064999967, 135.76422949999997, 'CNLNGN+ArialMT')],
#    146.38150899999997: [('Number of',
#      441.0649488,
#      146.38150899999997,
#      'CNLNGN+ArialMT'),
#     ('Hours', 508.73730915000004, 146.38150899999997, 'CNLNGN+ArialMT')],
#    148.96409049999997: [('The following labor hours were Reported today:',
#      85.6832634,
#      148.96409049999997,
#      'Arial-BoldMT')]}},
#  'REPORT NUMBER': {'100': [('100', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '101': [('101', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '102': [('102', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '105': [('105', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '106': [('106', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '107': [('107', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '108': [('108', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '109': [('109', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '112': [('112', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '113': [('113', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '114': [('114', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '119': [('119', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '120': [('120', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '121': [('121', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '122': [('122', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '123': [('123', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '126': [('126', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '127': [('127', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '91': [('91', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '92': [('92', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '93': [('93', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '94': [('94', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '95': [('95', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '96': [('96', 424.44, 718.1221125, 'CNLNGN+ArialMT')],
#   '98': [('98', 424.14, 718.1835895, 'CNLNGN+ArialMT')],
#   '99': [('99', 424.14, 718.1835895, 'CNLNGN+ArialMT')]}}

# %%
# todo headers if binding by position
header_items = []
body_items = []
for i in pairs:
    if next(iter(pairs[i]))[-1] == 'pos':
        header_items.append(i)
    else:
        body_items.append(i)
#print(header_items)
#print(body_items)

# %%
# create the table header for the part of report header
table_header = ''
for i in header_items:
    table_header += i.replace(' ', '_')+' '+'varchar(200)'
    if i!=header_items[-1]:
        table_header += ', '
print(table_header)
# Out:
# DATE varchar(200), REPORT_NUMBER varchar(200)

# %%
# row to be inserted into the table REPORT_HEADER
rows = []
for rep_num in set(report_num.values()): 
    row = ''
    for cat in header_items:
        row += "'"
        for t in data[cat][rep_num]:
            ##
            if len(t) == 0:
                row += 'NULL '
            else:
                row += t[0]+' '
        row += "'"
        if cat!=header_items[-1]:
            row += ', '
            #break
    rows.append(row)
    #print(row)
print(rows)
# Out:
# ["'22 Nov 2004 - Monday ', '112 '", "'05 Nov 2004 - Friday ', '95 '", "'24 Nov 2004 - Wednesday ', '114 '", "'09 Nov 2004 - Tuesday ', '99 '", "'01 Nov 2004 - Monday ', '91 '", "'19 Nov 2004 - Friday ', '109 '", "'NULL ', '96 '", "'07 Dec 2004 - Tuesday ', '127 '", "'29 Nov 2004 - Monday ', '119 '", "'23 Nov 2004 - Tuesday ', '113 '", "'02 Nov 2004 - Tuesday ', '92 '", "'03 Dec 2004 - Friday ', '123 '", "'03 Nov 2004 - Wednesday ', '93 '", "'NULL ', '98 '", "'01 Dec 2004 - Wednesday ', '121 '", "'04 Nov 2004 - Thursday ', '94 '", "'15 Nov 2004 - Monday ', '105 '", "'12 Nov 2004 - Friday ', '102 '", "'06 Dec 2004 - Monday ', '126 '", "'11 Nov 2004 - Thursday ', '101 '", "'17 Nov 2004 - Wednesday ', '107 '", "'16 Nov 2004 - Tuesday ', '106 '", "'18 Nov 2004 - Thursday ', '108 '", "'10 Nov 2004 - Wednesday ', '100 '", "'02 Dec 2004 - Thursday ', '122 '", "'30 Nov 2004 - Tuesday ', '120 '"]

# %% [markdown]
# # connect to MySQL

# %%
import MySQLdb
#connect to database
conn= MySQLdb.connect(
        host='localhost',
        port = 3306,
        user='root',
        #passwd='******',
        db ='test',
        )
cur = conn.cursor()

# %%
try:
    cur.execute("create table report_header(%s);" % table_header)
except Exception as err:
    print(err)

# %%
#insert a row
for row in rows:
    #print("insert into report_header values(%s);" % row)
    try:
        cur.execute("insert into report_header values(%s);" % row)
    except Exception as err:
        print(err)

# %%
# avoid encoding errors
conn.set_character_set('utf8')
cur.execute('SET NAMES utf8;')
cur.execute('SET CHARACTER SET utf8;')
cur.execute('SET character_set_connection=utf8;')
# Out:
# 0

# %%
cur.execute("create table tables_connetions(REPORT_NUMBER varchar(20), Category varchar(50), Table_name varchar(50));")
# Out:
# 0

# %%
from operator import itemgetter
import sys,traceback
#todo  zhongzhu documentation, mila, read if and extract table
def process(cat_page, cat, rep_num):
    tb_ct = 0
    text = ''
    col_num = 0
    header = ''
    table_name = ''
    for linepos, line in reversed(sorted(cat_page.items())):
        
        if len(line) == 1:
            header = ''
            table_name = cat
            text += line[0][0]+' '
            #print(line[0][0])
        elif len(line) >1:
            line.sort(key=itemgetter(1)) # sorted by y position
            if header == '' or col_num<len(line): # if number of colunms larger than last row, create a table
                header = 'REPORT_NUMBER varchar(20), '
                col_num = len(line)
                
                count = 0
                for i in line:
                    count += 1
                    header += re.sub(r"[^A-Za-z0-9]", '_', i[0])+str(count)+' '+'varchar(200)'
                    if i!=line[-1]:
                        header += ', '
                
                tb_ct += 1
                table = re.sub('[^A-Za-z0-9]','_',table_name)+'_table_'+str(tb_ct)
                try:
                    #print("create table %s(%s);" % (table, header))
                    cur.execute("create table %s(%s);" % (table, header))
                except Exception as err:
                    #print("Exception:")
                    if(err.args[0] != 1050):
                        print(err)
                        #print("create table %s(%s);" % (table, header))
                    #print("\n")
                    
                text += 'TABLE'+str(tb_ct)+'\n '
                cur.execute("insert into tables_connetions value('%s', '%s', '%s')" % (rep_num, re.sub(r"[^A-Za-z0-9]", '_', cat), table))
            elif len(line)==col_num:
                row = rep_num+', '
                for t in line:
                    row += "'"+re.sub(r"'|&|-", "_", t[0])+"'"
                    if t!=line[-1]:
                        row += ', '
                #print("insert into %s values(%s);" % (table, row))
                try:
                    cur.execute("insert into %s values(%s);" % (table, row))
                except Exception as err:
                    #print("Exception:")
                    print(err)
                    #print("insert into %s values(%s);" % (table, row))
                    #print("\n")
                
            else:
                header = ''
                text += line[0][0]+' '
                #print(line[0][0])
    return text

# %%
# create tables for categories in MySQL
for cat in body_items:
    h = re.sub(r"[^A-Za-z0-9]", '_', cat)
    if len(h) >= 30:
        h = h[:29]
    try:
        print("create table %s (REPORT_NUMBER varchar(20), %s varchar(10000))" % (h, h))
        cur.execute("create table %s (REPORT_NUMBER varchar(20), %s varchar(10000))" % (h, h))
    except Exception as err:
        print("Exception:")
        print(err)
        print("\n")
# Out:
# create table LABOR_HOURS (REPORT_NUMBER varchar(20), LABOR_HOURS varchar(10000))

# %%
for rep_num in set(report_num.values()): 
    for cat in body_items:
        h = re.sub(r"[^A-Za-z0-9]", '_', cat)
        if len(h) >= 30:
            h = h[:29]
        
        row = ''
        #print(cat+'-------------')
        if rep_num in data[cat]: 
            s = process(data[cat][rep_num], cat, rep_num.replace(',', '')).replace("'", "_")
            row += "'"+re.sub(r"&", "_", s)+"'" #replace symbols to avoid errors in SQL
        else:
            row += "'"+'NULL'+"'"
        try:
            cur.execute("insert into %s values(%s, %s)" % (h, rep_num.replace(',', ''), row))
        except Exception as err:
            #print("Exception:")
            print(err)
            #print("insert into %s values(%s, %s)" % (h, rep_num.replace(',', ''), row))
            #print("\n")

# %%
# close the connection to database
cur.close()
conn.commit()
conn.close()
